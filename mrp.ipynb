# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Analyse des données
df = pd.read_csv("C:/Users/Sarah/Desktop/Auto formation machine learning/graph.csv",sep=";")

# %%
df
# Out:
#      Year  Land_Annual
# 0    1880        -0.62
# 1    1881        -0.41
# 2    1882        -0.50
# 3    1883        -0.59
# 4    1884        -0.86
# ..    ...          ...
# 134  2014         1.03
# 135  2015         1.32
# 136  2016         1.48
# 137  2017         1.38
# 138  2018         1.22
#
# [139 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         139 non-null    int64
#  1   Land_Annual  139 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.3 KB

# %%
df.describe()
# Out:
#               Year  Land_Annual
# count   139.000000   139.000000
# mean   1949.000000     0.078417
# std      40.269923     0.502860
# min    1880.000000    -0.860000
# 25%    1914.500000    -0.270000
# 50%    1949.000000    -0.020000
# 75%    1983.500000     0.255000
# max    2018.000000     1.480000

# %%
plt.scatter(df['Year'], df['Land_Annual'])
plt.xlabel("Year")
plt.ylabel("Land Annual")
plt.title("Land Annual en fonction de year")
plt.show()

# %%
# Extraction de X
X = df[['Year']].values
y = df['Land_Annual']

# %% [markdown]
# # Regression linéair

# %%
# Déclaration du modèle linéaire
model_lineaire = LinearRegression()

# %%
model_lineaire.fit(X, y)
# Out:
# LinearRegression()

# %%
y_linear_pred = model_lineaire.predict(X)

# %%
mse = mean_squared_error(y, y_linear_pred)
mse
# Out:
# np.float64(0.05994096462800263)

# %%
r2_score_linear = r2_score(y, y_linear_pred)
r2_score_linear
# Out:
# 0.7612382660441059

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_linear_pred, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle')
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Regression polynomial de dégré 2

# %%
### Modèle de dégré 2
polynomial_feature_deg2 = PolynomialFeatures(degree=2)

# %%
X_poly_deg2 = polynomial_feature_deg2.fit_transform(X)

# %%
# Affichage de X
X
# Out:
# array([[1880],
#        [1881],
#        [1882],
#        [1883],
#        [1884],
#        [1885],
#        [1886],
#        [1887],
#        [1888],
#        [1889],
#        [1890],
#        [1891],
#        [1892],
#        [1893],
#        [1894],
#        [1895],
#        [1896],
#        [1897],
#        [1898],
#        [1899],
#        [1900],
#        [1901],
#        [1902],
#        [1903],
#        [1904],
#        [1905],
#        [1906],
#        [1907],
#        [1908],
#        [1909],
#        [1910],
#        [1911],
#        [1912],
#        [1913],
#        [1914],
#        [1915],
#        [1916],
#        [1917],
#        [1918],
#        [1919],
#        [1920],
#        [1921],
#        [1922],
#        [1923],
#        [1924],
#        [1925],
#        [1926],
#        [1927],
#        [1928],
#        [1929],
#        [1930],
#        [1931],
#        [1932],
#        [1933],
#        [1934],
#        [1935],
#        [1936],
#        [1937],
#        [1938],
#        [1939],
#        [1940],
#        [1941],
#        [1942],
#        [1943],
#        [1944],
#        [1945],
#        [1946],
#        [1947],
#        [1948],
#        [1949],
#        [1950],
#        [1951],
#        [1952],
#        [1953],
#        [1954],
#        [1955],
#        [1956],
#        [1957],
#        [1958],
#        [1959],
#        [1960],
#        [1961],
#        [1962],
#        [1963],
#        [1964],
#        [1965],
#        [1966],
#        [1967],
#        [1968],
#        [1969],
#        [1970],
#        [1971],
#        [1972],
#        [1973],
#        [1974],
#        [1975],
#        [1976],
#        [1977],
#        [1978],
#        [1979],
#        [1980],
#        [1981],
#        [1982],
#        [1983],
#        [1984],
#        [1985],
#        [1986],
#        [1987],
#        [1988],
#        [1989],
#        [1990],
#        [1991],
#        [1992],
#        [1993],
#        [1994],
#        [1995],
#        [1996],
#        [1997],
#        [1998],
#        [1999],
#        [2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018]])

# %%
# Affichage de X_ploy_deg
X_poly_deg2
# Out:
# array([[1.000000e+00, 1.880000e+03, 3.534400e+06],
#        [1.000000e+00, 1.881000e+03, 3.538161e+06],
#        [1.000000e+00, 1.882000e+03, 3.541924e+06],
#        [1.000000e+00, 1.883000e+03, 3.545689e+06],
#        [1.000000e+00, 1.884000e+03, 3.549456e+06],
#        [1.000000e+00, 1.885000e+03, 3.553225e+06],
#        [1.000000e+00, 1.886000e+03, 3.556996e+06],
#        [1.000000e+00, 1.887000e+03, 3.560769e+06],
#        [1.000000e+00, 1.888000e+03, 3.564544e+06],
#        [1.000000e+00, 1.889000e+03, 3.568321e+06],
#        [1.000000e+00, 1.890000e+03, 3.572100e+06],
#        [1.000000e+00, 1.891000e+03, 3.575881e+06],
#        [1.000000e+00, 1.892000e+03, 3.579664e+06],
#        [1.000000e+00, 1.893000e+03, 3.583449e+06],
#        [1.000000e+00, 1.894000e+03, 3.587236e+06],
#        [1.000000e+00, 1.895000e+03, 3.591025e+06],
#        [1.000000e+00, 1.896000e+03, 3.594816e+06],
#        [1.000000e+00, 1.897000e+03, 3.598609e+06],
#        [1.000000e+00, 1.898000e+03, 3.602404e+06],
#        [1.000000e+00, 1.899000e+03, 3.606201e+06],
#        [1.000000e+00, 1.900000e+03, 3.610000e+06],
#        [1.000000e+00, 1.901000e+03, 3.613801e+06],
#        [1.000000e+00, 1.902000e+03, 3.617604e+06],
#        [1.000000e+00, 1.903000e+03, 3.621409e+06],
#        [1.000000e+00, 1.904000e+03, 3.625216e+06],
#        [1.000000e+00, 1.905000e+03, 3.629025e+06],
#        [1.000000e+00, 1.906000e+03, 3.632836e+06],
#        [1.000000e+00, 1.907000e+03, 3.636649e+06],
#        [1.000000e+00, 1.908000e+03, 3.640464e+06],
#        [1.000000e+00, 1.909000e+03, 3.644281e+06],
#        [1.000000e+00, 1.910000e+03, 3.648100e+06],
#        [1.000000e+00, 1.911000e+03, 3.651921e+06],
#        [1.000000e+00, 1.912000e+03, 3.655744e+06],
#        [1.000000e+00, 1.913000e+03, 3.659569e+06],
#        [1.000000e+00, 1.914000e+03, 3.663396e+06],
#        [1.000000e+00, 1.915000e+03, 3.667225e+06],
#        [1.000000e+00, 1.916000e+03, 3.671056e+06],
#        [1.000000e+00, 1.917000e+03, 3.674889e+06],
#        [1.000000e+00, 1.918000e+03, 3.678724e+06],
#        [1.000000e+00, 1.919000e+03, 3.682561e+06],
#        [1.000000e+00, 1.920000e+03, 3.686400e+06],
#        [1.000000e+00, 1.921000e+03, 3.690241e+06],
#        [1.000000e+00, 1.922000e+03, 3.694084e+06],
#        [1.000000e+00, 1.923000e+03, 3.697929e+06],
#        [1.000000e+00, 1.924000e+03, 3.701776e+06],
#        [1.000000e+00, 1.925000e+03, 3.705625e+06],
#        [1.000000e+00, 1.926000e+03, 3.709476e+06],
#        [1.000000e+00, 1.927000e+03, 3.713329e+06],
#        [1.000000e+00, 1.928000e+03, 3.717184e+06],
#        [1.000000e+00, 1.929000e+03, 3.721041e+06],
#        [1.000000e+00, 1.930000e+03, 3.724900e+06],
#        [1.000000e+00, 1.931000e+03, 3.728761e+06],
#        [1.000000e+00, 1.932000e+03, 3.732624e+06],
#        [1.000000e+00, 1.933000e+03, 3.736489e+06],
#        [1.000000e+00, 1.934000e+03, 3.740356e+06],
#        [1.000000e+00, 1.935000e+03, 3.744225e+06],
#        [1.000000e+00, 1.936000e+03, 3.748096e+06],
#        [1.000000e+00, 1.937000e+03, 3.751969e+06],
#        [1.000000e+00, 1.938000e+03, 3.755844e+06],
#        [1.000000e+00, 1.939000e+03, 3.759721e+06],
#        [1.000000e+00, 1.940000e+03, 3.763600e+06],
#        [1.000000e+00, 1.941000e+03, 3.767481e+06],
#        [1.000000e+00, 1.942000e+03, 3.771364e+06],
#        [1.000000e+00, 1.943000e+03, 3.775249e+06],
#        [1.000000e+00, 1.944000e+03, 3.779136e+06],
#        [1.000000e+00, 1.945000e+03, 3.783025e+06],
#        [1.000000e+00, 1.946000e+03, 3.786916e+06],
#        [1.000000e+00, 1.947000e+03, 3.790809e+06],
#        [1.000000e+00, 1.948000e+03, 3.794704e+06],
#        [1.000000e+00, 1.949000e+03, 3.798601e+06],
#        [1.000000e+00, 1.950000e+03, 3.802500e+06],
#        [1.000000e+00, 1.951000e+03, 3.806401e+06],
#        [1.000000e+00, 1.952000e+03, 3.810304e+06],
#        [1.000000e+00, 1.953000e+03, 3.814209e+06],
#        [1.000000e+00, 1.954000e+03, 3.818116e+06],
#        [1.000000e+00, 1.955000e+03, 3.822025e+06],
#        [1.000000e+00, 1.956000e+03, 3.825936e+06],
#        [1.000000e+00, 1.957000e+03, 3.829849e+06],
#        [1.000000e+00, 1.958000e+03, 3.833764e+06],
#        [1.000000e+00, 1.959000e+03, 3.837681e+06],
#        [1.000000e+00, 1.960000e+03, 3.841600e+06],
#        [1.000000e+00, 1.961000e+03, 3.845521e+06],
#        [1.000000e+00, 1.962000e+03, 3.849444e+06],
#        [1.000000e+00, 1.963000e+03, 3.853369e+06],
#        [1.000000e+00, 1.964000e+03, 3.857296e+06],
#        [1.000000e+00, 1.965000e+03, 3.861225e+06],
#        [1.000000e+00, 1.966000e+03, 3.865156e+06],
#        [1.000000e+00, 1.967000e+03, 3.869089e+06],
#        [1.000000e+00, 1.968000e+03, 3.873024e+06],
#        [1.000000e+00, 1.969000e+03, 3.876961e+06],
#        [1.000000e+00, 1.970000e+03, 3.880900e+06],
#        [1.000000e+00, 1.971000e+03, 3.884841e+06],
#        [1.000000e+00, 1.972000e+03, 3.888784e+06],
#        [1.000000e+00, 1.973000e+03, 3.892729e+06],
#        [1.000000e+00, 1.974000e+03, 3.896676e+06],
#        [1.000000e+00, 1.975000e+03, 3.900625e+06],
#        [1.000000e+00, 1.976000e+03, 3.904576e+06],
#        [1.000000e+00, 1.977000e+03, 3.908529e+06],
#        [1.000000e+00, 1.978000e+03, 3.912484e+06],
#        [1.000000e+00, 1.979000e+03, 3.916441e+06],
#        [1.000000e+00, 1.980000e+03, 3.920400e+06],
#        [1.000000e+00, 1.981000e+03, 3.924361e+06],
#        [1.000000e+00, 1.982000e+03, 3.928324e+06],
#        [1.000000e+00, 1.983000e+03, 3.932289e+06],
#        [1.000000e+00, 1.984000e+03, 3.936256e+06],
#        [1.000000e+00, 1.985000e+03, 3.940225e+06],
#        [1.000000e+00, 1.986000e+03, 3.944196e+06],
#        [1.000000e+00, 1.987000e+03, 3.948169e+06],
#        [1.000000e+00, 1.988000e+03, 3.952144e+06],
#        [1.000000e+00, 1.989000e+03, 3.956121e+06],
#        [1.000000e+00, 1.990000e+03, 3.960100e+06],
#        [1.000000e+00, 1.991000e+03, 3.964081e+06],
#        [1.000000e+00, 1.992000e+03, 3.968064e+06],
#        [1.000000e+00, 1.993000e+03, 3.972049e+06],
#        [1.000000e+00, 1.994000e+03, 3.976036e+06],
#        [1.000000e+00, 1.995000e+03, 3.980025e+06],
#        [1.000000e+00, 1.996000e+03, 3.984016e+06],
#        [1.000000e+00, 1.997000e+03, 3.988009e+06],
#        [1.000000e+00, 1.998000e+03, 3.992004e+06],
#        [1.000000e+00, 1.999000e+03, 3.996001e+06],
#        [1.000000e+00, 2.000000e+03, 4.000000e+06],
#        [1.000000e+00, 2.001000e+03, 4.004001e+06],
#        [1.000000e+00, 2.002000e+03, 4.008004e+06],
#        [1.000000e+00, 2.003000e+03, 4.012009e+06],
#        [1.000000e+00, 2.004000e+03, 4.016016e+06],
#        [1.000000e+00, 2.005000e+03, 4.020025e+06],
#        [1.000000e+00, 2.006000e+03, 4.024036e+06],
#        [1.000000e+00, 2.007000e+03, 4.028049e+06],
#        [1.000000e+00, 2.008000e+03, 4.032064e+06],
#        [1.000000e+00, 2.009000e+03, 4.036081e+06],
#        [1.000000e+00, 2.010000e+03, 4.040100e+06],
#        [1.000000e+00, 2.011000e+03, 4.044121e+06],
#        [1.000000e+00, 2.012000e+03, 4.048144e+06],
#        [1.000000e+00, 2.013000e+03, 4.052169e+06],
#        [1.000000e+00, 2.014000e+03, 4.056196e+06],
#        [1.000000e+00, 2.015000e+03, 4.060225e+06],
#        [1.000000e+00, 2.016000e+03, 4.064256e+06],
#        [1.000000e+00, 2.017000e+03, 4.068289e+06],
#        [1.000000e+00, 2.018000e+03, 4.072324e+06]])

# %%
X_poly_deg2.shape
# Out:
# (139, 3)

# %%
# Entrainement du modèle de dégré 2
model_lineaire.fit(X_poly_deg2, y)
# Out:
# LinearRegression()

# %%
# La prédiction de notre modèle de dégré
y_pred_deg2 = model_lineaire.predict(X_poly_deg2)

# %%
mse = mean_squared_error(y, y_pred_deg2)
mse
# Out:
# np.float64(0.04274182438951053)

# %%
r2_score_linear = r2_score(y, y_pred_deg2)
r2_score_linear
# Out:
# 0.8297472827304094

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_pred_deg2, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle pour le modèle de dégré 2')
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Regression polynomial de dégré 3

# %%
### Modèle de dégré 3
polynomial_feature_deg3 = PolynomialFeatures(degree=3)

# %%
X_poly_deg3 = polynomial_feature_deg3.fit_transform(X)

# %%
# Entrainement du modèle de dégré 3
model_lineaire.fit(X_poly_deg3, y)
# Out:
# LinearRegression()

# %%
# La prédiction de notre modèle de dégré 3
y_pred_deg3 = model_lineaire.predict(X_poly_deg3)

# %%
mse = mean_squared_error(y, y_pred_deg3)
mse
# Out:
# np.float64(0.029227927661416596)

# %%
r2_score_linear = r2_score(y, y_pred_deg3)
r2_score_linear
# Out:
# 0.8835769372133675

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_pred_deg3, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle pour le modèle de dégré 3')
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # EXERCICE

# %% [markdown]
# # Regression polynomial de dégré 4

# %%
### Modèle de dégré 4
polynomial_feature_deg4 = PolynomialFeatures(degree=4)

# %%
X_poly_deg4 = polynomial_feature_deg4.fit_transform(X)

# %%
# Entrainement du modèle de dégré 4
model_lineaire.fit(X_poly_deg4, y)
# Out:
# LinearRegression()

# %%
# La prédiction de notre modèle de dégré 4
y_pred_deg4 = model_lineaire.predict(X_poly_deg4)

# %%
mse = mean_squared_error(y, y_pred_deg4)
mse
# Out:
# np.float64(0.029196297757656028)

# %%
r2_score_linear = r2_score(y, y_pred_deg4)
r2_score_linear
# Out:
# 0.8837029280230517

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_pred_deg4, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle pour le modèle de dégré 4')
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Regression polynomial de dégré 5

# %%
### Modèle de dégré 5
polynomial_feature_deg5 = PolynomialFeatures(degree=5)

# %%
X_poly_deg5 = polynomial_feature_deg5.fit_transform(X)

# %%
# Entrainement du modèle de dégré 5
model_lineaire.fit(X_poly_deg5, y)
# Out:
# LinearRegression()

# %%
# La prédiction de notre modèle de dégré 5
y_pred_deg5 = model_lineaire.predict(X_poly_deg5)

# %%
mse = mean_squared_error(y, y_pred_deg5)
mse
# Out:
# np.float64(0.02917108358199622)

# %%
r2_score_linear = r2_score(y, y_pred_deg5)
r2_score_linear
# Out:
# 0.8838033631818478

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_pred_deg5, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle pour le modèle de dégré 5')
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Regression polynomial de dégré 6

# %%
### Modèle de dégré 6
polynomial_feature_deg6 = PolynomialFeatures(degree=6)

# %%
X_poly_deg6 = polynomial_feature_deg6.fit_transform(X)

# %%
# Entrainement du modèle de dégré 5
model_lineaire.fit(X_poly_deg6, y)
# Out:
# LinearRegression()

# %%
# La prédiction de notre modèle de dégré 5
y_pred_deg6 = model_lineaire.predict(X_poly_deg6)

# %%
mse = mean_squared_error(y, y_pred_deg6)
mse
# Out:
# np.float64(0.029152110379606216)

# %%
r2_score_linear = r2_score(y, y_pred_deg6)
r2_score_linear
# Out:
# 0.8838789387874365

# %%
# Visualisation des résultats
plt.figure(figsize=(10, 6))

# Tracer les données réelles
plt.scatter(X, y, color='blue', label='Données Réelles')

# Tracer les prédictions du modèle
plt.plot(X, y_pred_deg6, color='red', linewidth=2, label='Prédictions du Modèle')

# Ajouter des labels et un titre
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Cible')
plt.title('Données Réelles et Prédictions du Modèle pour le modèle de dégré 6')
plt.legend()

# Afficher le graphique
plt.show()
